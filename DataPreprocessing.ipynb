# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
from glob import glob

# %%
HE_Antigen_list=glob('../../data/IHC4BC_Compressed/Images/HandE/**/')
IHC_Antigen_list=[f.replace('HandE','IHC') for f in HE_Antigen_list]
